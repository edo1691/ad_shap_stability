# %% [markdown]
# # iForest

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## General libraries

# %%
import os
import sys

import pandas as pd
import numpy as np

from os.path import join
import json
import datetime

import shap
from shap_selection import feature_selection

import time

# %% [markdown]
# ### Load enviroment variables

# %%
from dotenv import load_dotenv
load_dotenv('../.env')

code_root = os.environ['CODE_ROOT']
cfg_path = os.environ['CFG_PATH']
data_root = os.environ['DATA_ROOT']

sys.path.insert(0, code_root)

# %% [markdown]
# ### Specific libraries

# %%
from src.load.functions import get_fs_dataset, fs_datasets_hyperparams
from src.feature_selection.functions import fs_iforest_with_shap, shap_ranks, process_fi

# %% [markdown]
# ## General parameters

# %%
n_iter_fs = 1
n_iter = 1
contamination_percentage = [0.8] 
trees = [25, 50, 100]
group = 0

# %% [markdown]
# ## Data set

# %%
dataset_id = 'allianz'
data = get_fs_dataset(dataset_id, data_root)
hyper = fs_datasets_hyperparams(dataset_id)
data.shape
# Out:
# (42358, 48)

# %%
excluded_cols = []

# %%
data
# Out:
#              weekday_surv_sin  weekday_declaration  reporting_delay_in_days  \
# NO_SIN
# 20121062512                 3                    2                     3688
# 20141061929                 6                    4                     3134
# 20151060794                 3                    0                     2594
# 20151060795                 6                    2                     2355
# 20171061308                 1                    2                     1681
# ...                       ...                  ...                      ...
# 20231021195                 1                    4                       17
# 20231021196                 4                    2                       12
# 20231021197                 6                    3                        4
# 20231021198                 2                    3                        1
# 20231021199                 1                    3                        2
#
#              contract_age_in_days  d_surv_sin_is_weekend_True  \
# NO_SIN
# 20121062512                 -2269                         0.0
# 20141061929                   189                         1.0
# 20151060794                    17                         0.0
# 20151060795                  3212                         1.0
# 20171061308                   164                         0.0
# ...                           ...                         ...
# 20231021195                   175                         0.0
# 20231021196                   139                         0.0
# 20231021197                    89                         1.0
# 20231021198                   212                         0.0
# 20231021199                    66                         0.0
#
#              d_dcl_is_weekend_True  is_closed_True  is_serious_sinister_True  \
# NO_SIN
# 20121062512                    0.0             1.0                       0.0
# 20141061929                    0.0             0.0                       0.0
# 20151060794                    0.0             1.0                       0.0
# 20151060795                    0.0             1.0                       0.0
# 20171061308                    0.0             0.0                       0.0
# ...                            ...             ...                       ...
# 20231021195                    0.0             0.0                       0.0
# 20231021196                    0.0             0.0                       0.0
# 20231021197                    0.0             0.0                       0.0
# 20231021198                    0.0             0.0                       0.0
# 20231021199                    0.0             0.0                       0.0
#
#              has_judiciary_procedure_True  C_CAU_13  ...  RESP_CIE_5  \
# NO_SIN                                               ...
# 20121062512                           0.0       0.0  ...         0.0
# 20141061929                           0.0       0.0  ...         0.0
# 20151060794                           0.0       0.0  ...         0.0
# 20151060795                           0.0       0.0  ...         0.0
# 20171061308                           0.0       0.0  ...         0.0
# ...                                   ...       ...  ...         ...
# 20231021195                           0.0       0.0  ...         1.0
# 20231021196                           0.0       0.0  ...         0.0
# 20231021197                           0.0       0.0  ...         0.0
# 20231021198                           0.0       0.0  ...         0.0
# 20231021199                           0.0       0.0  ...         0.0
#
#              RESP_CIE_9  RESP_CIE_infrequent_sklearn  C_APPLN_MALUS_1  \
# NO_SIN
# 20121062512         0.0                          0.0              0.0
# 20141061929         0.0                          0.0              0.0
# 20151060794         0.0                          0.0              0.0
# 20151060795         0.0                          0.0              0.0
# 20171061308         0.0                          0.0              0.0
# ...                 ...                          ...              ...
# 20231021195         0.0                          0.0              0.0
# 20231021196         0.0                          0.0              0.0
# 20231021197         0.0                          0.0              0.0
# 20231021198         0.0                          0.0              0.0
# 20231021199         0.0                          0.0              0.0
#
#              C_APPLN_MALUS_2  C_APPLN_MALUS_3  CNT_TY_GES_P  IND_PMT_DIR_N  \
# NO_SIN
# 20121062512              0.0              0.0           1.0            1.0
# 20141061929              0.0              0.0           1.0            1.0
# 20151060794              0.0              0.0           1.0            1.0
# 20151060795              0.0              0.0           1.0            1.0
# 20171061308              0.0              0.0           1.0            1.0
# ...                      ...              ...           ...            ...
# 20231021195              0.0              0.0           1.0            1.0
# 20231021196              0.0              0.0           1.0            1.0
# 20231021197              0.0              0.0           1.0            1.0
# 20231021198              0.0              0.0           1.0            1.0
# 20231021199              0.0              0.0           1.0            1.0
#
#              IND_PMT_DIR_Y  C_ORGN_OUVT_C
# NO_SIN
# 20121062512            0.0            1.0
# 20141061929            0.0            1.0
# 20151060794            0.0            1.0
# 20151060795            0.0            1.0
# 20171061308            0.0            1.0
# ...                    ...            ...
# 20231021195            0.0            1.0
# 20231021196            0.0            1.0
# 20231021197            0.0            1.0
# 20231021198            0.0            1.0
# 20231021199            0.0            1.0
#
# [42358 rows x 48 columns]

# %% [markdown]
# ### iForest

# %% [markdown]
# ## Parameters

# %%
path_fi_shap = os.path.join(data_root, "outputs", f"{dataset_id}_fi_shap")

# %% [markdown]
# ## Feature selection by SHAP

# %%
fs_shap, fi_shap, _ = fs_iforest_with_shap(data, contamination_percentage=contamination_percentage, excluded_cols=excluded_cols, n_iter_fs=n_iter_fs)
# Out:
#  99%|===================| 8395/8472 [00:31<00:00]

# %%
fi_shap_all = process_fi(fi_shap, 10)

# %%
fi_shap_all
# Out:
#     n_feats  cum_value  cum_value_percentage  n_feats_percentage  \
# 0         2   0.471160             10.109160            4.347826
# 1         4   0.914633             19.624280            8.695652
# 2         6   1.332647             28.593162           13.043478
# 3         9   1.923959             41.280298           19.565217
# 4        11   2.287247             49.074969           23.913043
# 5        14   2.782953             59.710800           30.434783
# 6        18   3.307418             70.963679           39.130435
# 7        22   3.727265             79.971873           47.826087
# 8        28   4.216176             90.461924           60.869565
# 9        46   4.660719            100.000000          100.000000
# 10       48   4.660719            100.000000          100.000000
#
#                                         feat_selected
# 0                         [C_APPLN_MALUS_1, C_CAU_40]
# 1   [C_APPLN_MALUS_1, C_CAU_40, d_surv_sin_is_week...
# 2   [C_APPLN_MALUS_1, C_CAU_40, d_surv_sin_is_week...
# 3   [C_APPLN_MALUS_1, C_CAU_40, d_surv_sin_is_week...
# 4   [C_APPLN_MALUS_1, C_CAU_40, d_surv_sin_is_week...
# 5   [C_APPLN_MALUS_1, C_CAU_40, d_surv_sin_is_week...
# 6   [C_APPLN_MALUS_1, C_CAU_40, d_surv_sin_is_week...
# 7   [C_APPLN_MALUS_1, C_CAU_40, d_surv_sin_is_week...
# 8   [C_APPLN_MALUS_1, C_CAU_40, d_surv_sin_is_week...
# 9   [C_APPLN_MALUS_1, C_CAU_40, d_surv_sin_is_week...
# 10  [C_APPLN_MALUS_1, C_CAU_40, d_surv_sin_is_week...

# %%
fi_shap_all.to_parquet(path_fi_shap)

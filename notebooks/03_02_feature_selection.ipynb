# %% [markdown]
# # iForest

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## General libraries

# %%
import os
import sys

import pandas as pd
import numpy as np

from os.path import join
import json
import datetime

import shap
from shap_selection import feature_selection

import time

# %% [markdown]
# ### Load enviroment variables

# %%
from dotenv import load_dotenv
load_dotenv('../.env')

code_root = os.environ['CODE_ROOT']
cfg_path = os.environ['CFG_PATH']
data_root = os.environ['DATA_ROOT']

sys.path.insert(0, code_root)

# %% [markdown]
# ### Specific libraries

# %%
from src.load.functions import get_fs_dataset, fs_datasets_hyperparams
from src.feature_selection.functions import fs_iforest_with_shap, shap_ranks, process_fi

# %% [markdown]
# ## General parameters

# %%
n_iter_fs = 1
n_iter = 1
contamination_percentage = [1] 
trees = [25, 50, 100]
group = 10

excluded_cols = []

# %% [markdown]
# ## Allinz claims data

# %% [markdown]
# ----
# **Dataset source**: Private dataset from Allianz Benelux, which contain the claims data from clients during 201801-202312
#
# **Additional sources**:
#
# ----

# %%
dataset_id = 'allianz'
data = get_fs_dataset(dataset_id, data_root)
hyper = fs_datasets_hyperparams(dataset_id)
data.shape
# Out:
# (42358, 36)

# %% [markdown]
# ### iForest

# %% [markdown]
# ## Parameters

# %%
path_fi_shap = os.path.join(data_root, "outputs", f"{dataset_id}_fi_shap")

# %% [markdown]
# ## Feature selection by SHAP

# %%
fs_shap, fi_shap, _ = fs_iforest_with_shap(data, contamination_percentage=contamination_percentage, excluded_cols=excluded_cols, n_iter_fs=n_iter_fs)
# Out:
#  99%|===================| 8400/8472 [00:39<00:00]

# %%
fi_shap
# Out:
#                           feature     value  per_value  cum_value  \
# 0                        C_CAU_50  0.365445   7.859328   0.365445
# 1       C_FORM_infrequent_sklearn  0.329101   7.077706   0.694545
# 2                  C_FAM_PROD_A02  0.270197   5.810914   0.964743
# 3                   IND_PMT_DIR_Y  0.229788   4.941870   1.194531
# 4      d_surv_sin_is_weekend_True  0.213701   4.595892   1.408232
# 5     RESP_CIE_infrequent_sklearn  0.211525   4.549101   1.619757
# 6                       C_FORM_17  0.204248   4.392606   1.824005
# 7                        C_CAU_40  0.196947   4.235588   2.020952
# 8                 C_APPLN_MALUS_1  0.194823   4.189906   2.215775
# 9                       C_FORM_11  0.188479   4.053470   2.404255
# 10                   CNT_TY_GES_P  0.182239   3.919264   2.586493
# 11                  IND_PMT_DIR_N  0.182011   3.914365   2.768504
# 12                 is_closed_True  0.178157   3.831486   2.946662
# 13           contract_age_in_days  0.165038   3.549347   3.111700
# 14                       C_CAU_69  0.157838   3.394498   3.269538
# 15       C_CAU_infrequent_sklearn  0.151623   3.260842   3.421161
# 16                         C_ET_2  0.132584   2.851385   3.553746
# 17                     RESP_CIE_2  0.132250   2.844188   3.685995
# 18                 C_FAM_PROD_A15  0.114597   2.464536   3.800592
# 19        reporting_delay_in_days  0.104397   2.245192   3.904989
# 20                     RESP_CIE_4  0.101789   2.189091   4.006778
# 21            weekday_declaration  0.100231   2.155583   4.107009
# 22               weekday_surv_sin  0.094293   2.027887   4.201302
# 23                 C_FAM_PROD_A03  0.087212   1.875589   4.288514
# 24                    C_NAT_SIN_M  0.080582   1.733021   4.369096
# 25                      C_FORM_12  0.079201   1.703303   4.448297
# 26  C_FAM_PROD_infrequent_sklearn  0.078357   1.685159   4.526654
# 27          d_dcl_is_weekend_True  0.038525   0.828530   4.565179
# 28                     RESP_CIE_1  0.037385   0.804000   4.602563
# 29                         C_ET_1  0.031076   0.668321   4.633639
# 30                         C_ET_3  0.013650   0.293558   4.647289
# 31   has_judiciary_procedure_True  0.002326   0.050014   4.649614
# 32                C_APPLN_MALUS_2  0.000151   0.003241   4.649765
# 33                C_APPLN_MALUS_3  0.000057   0.001222   4.649822
# 34       is_serious_sinister_True  0.000000   0.000000   4.649822
# 35                  C_ORGN_OUVT_C  0.000000   0.000000   4.649822
#
#     cum_value_percentage
# 0               7.859328
# 1              14.937034
# 2              20.747947
# 3              25.689817
# 4              30.285709
# 5              34.834810
# 6              39.227416
# 7              43.463005
# 8              47.652910
# 9              51.706380
# 10             55.625644
# 11             59.540009
# 12             63.371495
# 13             66.920841
# 14             70.315339
# 15             73.576181
# 16             76.427566
# 17             79.271754
# 18             81.736290
# 19             83.981483
# 20             86.170574
# 21             88.326157
# 22             90.354043
# 23             92.229632
# 24             93.962653
# 25             95.665956
# 26             97.351115
# 27             98.179645
# 28             98.983644
# 29             99.651965
# 30             99.945523
# 31             99.995538
# 32             99.998778
# 33            100.000000
# 34            100.000000
# 35            100.000000

# %%
fi_shap_all = process_fi(fi_shap, group)

# %%
fi_shap_all
# Out:
#     n_feats  cum_value  cum_value_percentage  n_feats_percentage  \
# 0         2   0.560016             12.630282            5.882353
# 1         3   0.814389             18.367271            8.823529
# 2         5   1.301811             29.360323           14.705882
# 3         7   1.747532             39.412870           20.588235
# 4         9   2.139530             48.253776           26.470588
# 5        12   2.630259             59.321415           35.294118
# 6        15   3.074816             69.347707           44.117647
# 7        19   3.568848             80.489815           55.882353
# 8        23   3.977493             89.706170           67.647059
# 9        34   4.433912            100.000000          100.000000
# 10       36   4.433912            100.000000          100.000000
#
#                                         feat_selected
# 0               [C_FORM_infrequent_sklearn, C_CAU_50]
# 1   [C_FORM_infrequent_sklearn, C_CAU_50, C_FAM_PR...
# 2   [C_FORM_infrequent_sklearn, C_CAU_50, C_FAM_PR...
# 3   [C_FORM_infrequent_sklearn, C_CAU_50, C_FAM_PR...
# 4   [C_FORM_infrequent_sklearn, C_CAU_50, C_FAM_PR...
# 5   [C_FORM_infrequent_sklearn, C_CAU_50, C_FAM_PR...
# 6   [C_FORM_infrequent_sklearn, C_CAU_50, C_FAM_PR...
# 7   [C_FORM_infrequent_sklearn, C_CAU_50, C_FAM_PR...
# 8   [C_FORM_infrequent_sklearn, C_CAU_50, C_FAM_PR...
# 9   [C_FORM_infrequent_sklearn, C_CAU_50, C_FAM_PR...
# 10  [C_FORM_infrequent_sklearn, C_CAU_50, C_FAM_PR...

# %%
fi_shap_all.to_parquet(path_fi_shap)

# %%
fi_shap_all = pd.read_parquet(path_fi_shap)

# %%
fi_shap_all.feat_selected[10]
# Out:
# array(['C_FORM_infrequent_sklearn', 'C_CAU_50', 'C_FAM_PROD_A02',
#        'IND_PMT_DIR_N', 'C_CAU_40', 'd_surv_sin_is_weekend_True',
#        'C_APPLN_MALUS_1', 'IND_PMT_DIR_Y', 'C_FORM_11', 'RESP_CIE_2',
#        'C_FORM_17', 'C_CAU_infrequent_sklearn', 'is_closed_True',
#        'contract_age_in_days', 'RESP_CIE_infrequent_sklearn', 'C_CAU_69',
#        'CNT_TY_GES_P', 'C_FORM_12', 'weekday_declaration',
#        'C_FAM_PROD_A15', 'C_ET_2', 'C_FAM_PROD_A03',
#        'reporting_delay_in_days', 'RESP_CIE_4',
#        'C_FAM_PROD_infrequent_sklearn', 'weekday_surv_sin', 'C_ET_1',
#        'C_NAT_SIN_M', 'd_dcl_is_weekend_True', 'RESP_CIE_1', 'C_ET_3',
#        'has_judiciary_procedure_True', 'C_APPLN_MALUS_2',
#        'C_APPLN_MALUS_3', 'C_ORGN_OUVT_C', 'is_serious_sinister_True'],
#       dtype=object)

# %% [markdown]
# # iForest

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## General libraries

# %%
import os
import sys

import pandas as pd
import numpy as np

from os.path import join
import json
import datetime

import shap
from shap_selection import feature_selection

import time

# %% [markdown]
# ### Load enviroment variables

# %%
from dotenv import load_dotenv
load_dotenv('../.env')

code_root = os.environ['CODE_ROOT']
cfg_path = os.environ['CFG_PATH']
data_root = os.environ['DATA_ROOT']

sys.path.insert(0, code_root)

# %% [markdown]
# ### Specific libraries

# %%
from src.load.functions import get_fs_dataset, fs_datasets_hyperparams
from src.feature_selection.functions import fs_iforest_with_shap, shap_ranks, process_fi

# %% [markdown]
# ## General parameters

# %%
n_iter_fs = 1
n_iter = 1
contamination_percentage = [0.8] 
trees = [25, 50, 100]
group = 0

# %% [markdown]
# ## Data set

# %%
dataset_id = 'allianz'
data = get_fs_dataset(dataset_id, data_root)
hyper = fs_datasets_hyperparams(dataset_id)
data.shape
# Out:
# (42358, 36)

# %%
excluded_cols = []

# %%
data
# Out:
#              weekday_surv_sin  weekday_declaration  reporting_delay_in_days  \
# NO_SIN
# 20121062512                 3                    2                     3688
# 20141061929                 6                    4                     3134
# 20151060794                 3                    0                     2594
# 20151060795                 6                    2                     2355
# 20171061308                 1                    2                     1681
# ...                       ...                  ...                      ...
# 20231021195                 1                    4                       17
# 20231021196                 4                    2                       12
# 20231021197                 6                    3                        4
# 20231021198                 2                    3                        1
# 20231021199                 1                    3                        2
#
#              contract_age_in_days  d_surv_sin_is_weekend_True  \
# NO_SIN
# 20121062512                 -2269                         0.0
# 20141061929                   189                         1.0
# 20151060794                    17                         0.0
# 20151060795                  3212                         1.0
# 20171061308                   164                         0.0
# ...                           ...                         ...
# 20231021195                   175                         0.0
# 20231021196                   139                         0.0
# 20231021197                    89                         1.0
# 20231021198                   212                         0.0
# 20231021199                    66                         0.0
#
#              d_dcl_is_weekend_True  is_closed_True  is_serious_sinister_True  \
# NO_SIN
# 20121062512                    0.0             1.0                       0.0
# 20141061929                    0.0             0.0                       0.0
# 20151060794                    0.0             1.0                       0.0
# 20151060795                    0.0             1.0                       0.0
# 20171061308                    0.0             0.0                       0.0
# ...                            ...             ...                       ...
# 20231021195                    0.0             0.0                       0.0
# 20231021196                    0.0             0.0                       0.0
# 20231021197                    0.0             0.0                       0.0
# 20231021198                    0.0             0.0                       0.0
# 20231021199                    0.0             0.0                       0.0
#
#              has_judiciary_procedure_True  C_CAU_40  ...  RESP_CIE_2  \
# NO_SIN                                               ...
# 20121062512                           0.0       0.0  ...         1.0
# 20141061929                           0.0       0.0  ...         1.0
# 20151060794                           0.0       0.0  ...         0.0
# 20151060795                           0.0       0.0  ...         0.0
# 20171061308                           0.0       0.0  ...         0.0
# ...                                   ...       ...  ...         ...
# 20231021195                           0.0       0.0  ...         0.0
# 20231021196                           0.0       0.0  ...         1.0
# 20231021197                           0.0       1.0  ...         1.0
# 20231021198                           0.0       0.0  ...         1.0
# 20231021199                           0.0       0.0  ...         0.0
#
#              RESP_CIE_4  RESP_CIE_infrequent_sklearn  C_APPLN_MALUS_1  \
# NO_SIN
# 20121062512         0.0                          0.0              0.0
# 20141061929         0.0                          0.0              0.0
# 20151060794         0.0                          0.0              0.0
# 20151060795         1.0                          0.0              0.0
# 20171061308         1.0                          0.0              0.0
# ...                 ...                          ...              ...
# 20231021195         0.0                          1.0              0.0
# 20231021196         0.0                          0.0              0.0
# 20231021197         0.0                          0.0              0.0
# 20231021198         0.0                          0.0              0.0
# 20231021199         0.0                          0.0              0.0
#
#              C_APPLN_MALUS_2  C_APPLN_MALUS_3  CNT_TY_GES_P  IND_PMT_DIR_N  \
# NO_SIN
# 20121062512              0.0              0.0           1.0            1.0
# 20141061929              0.0              0.0           1.0            1.0
# 20151060794              0.0              0.0           1.0            1.0
# 20151060795              0.0              0.0           1.0            1.0
# 20171061308              0.0              0.0           1.0            1.0
# ...                      ...              ...           ...            ...
# 20231021195              0.0              0.0           1.0            1.0
# 20231021196              0.0              0.0           1.0            1.0
# 20231021197              0.0              0.0           1.0            1.0
# 20231021198              0.0              0.0           1.0            1.0
# 20231021199              0.0              0.0           1.0            1.0
#
#              IND_PMT_DIR_Y  C_ORGN_OUVT_C
# NO_SIN
# 20121062512            0.0            1.0
# 20141061929            0.0            1.0
# 20151060794            0.0            1.0
# 20151060795            0.0            1.0
# 20171061308            0.0            1.0
# ...                    ...            ...
# 20231021195            0.0            1.0
# 20231021196            0.0            1.0
# 20231021197            0.0            1.0
# 20231021198            0.0            1.0
# 20231021199            0.0            1.0
#
# [42358 rows x 36 columns]

# %% [markdown]
# ### iForest

# %% [markdown]
# ## Parameters

# %%
path_fi_shap = os.path.join(data_root, "outputs", f"{dataset_id}_fi_shap.parquet")

# %% [markdown]
# ## Feature selection by SHAP

# %%
fs_shap, fi_shap, _ = fs_iforest_with_shap(data, contamination_percentage=contamination_percentage, excluded_cols=excluded_cols, n_iter_fs=n_iter_fs)
# Out:
#  98%|===================| 8297/8472 [00:44<00:00]

# %%
fi_shap_all = process_fi(fi_shap, 10)

# %%
fi_shap_all
# Out:
#     n_feats  cum_value  cum_value_percentage  n_feats_percentage  \
# 0         2   0.561446             12.542027            5.882353
# 1         3   0.826335             18.459324            8.823529
# 2         5   1.305672             29.167147           14.705882
# 3         7   1.768254             39.500673           20.588235
# 4         9   2.210064             49.370173           26.470588
# 5        12   2.754617             61.534850           35.294118
# 6        15   3.192019             71.305880           44.117647
# 7        18   3.568851             79.723858           52.941176
# 8        23   4.064477             90.795552           67.647059
# 9        34   4.476516            100.000000          100.000000
# 10       36   4.476516            100.000000          100.000000
#
#                                         feat_selected
# 0              [C_CAU_50, d_surv_sin_is_weekend_True]
# 1    [C_CAU_50, d_surv_sin_is_weekend_True, C_CAU_40]
# 2   [C_CAU_50, d_surv_sin_is_weekend_True, C_CAU_4...
# 3   [C_CAU_50, d_surv_sin_is_weekend_True, C_CAU_4...
# 4   [C_CAU_50, d_surv_sin_is_weekend_True, C_CAU_4...
# 5   [C_CAU_50, d_surv_sin_is_weekend_True, C_CAU_4...
# 6   [C_CAU_50, d_surv_sin_is_weekend_True, C_CAU_4...
# 7   [C_CAU_50, d_surv_sin_is_weekend_True, C_CAU_4...
# 8   [C_CAU_50, d_surv_sin_is_weekend_True, C_CAU_4...
# 9   [C_CAU_50, d_surv_sin_is_weekend_True, C_CAU_4...
# 10  [C_CAU_50, d_surv_sin_is_weekend_True, C_CAU_4...

# %%
fi_shap_all.to_parquet(path_fi_shap)
